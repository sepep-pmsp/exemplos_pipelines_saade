# %%
import requests

# %%
#ideia: fazer uma consulta separada para o perimetro
#atentar que tem coisa que pode ter mais de uma

dados_imovel = {
    'divisoes_admnistrativas' : {
        'distrito' : 'Pinheiros',
        'subprefeitura' : 'Pinheiros',
        'zona' : 'Oeste'
    },
    'legislacao_urbanistica' : {
        'macrozoneamento' : {
            'zona_urbana' : True,
            'macrozona' : 'Macrozona de Estruturação e Qualificação Urbana',
            'macroarea' : 'Macroárea de Estruturação Metropolitana',
            'setor' : 'Setor Orla Ferroviária e Fluvial',
            'subsetor' : 'Arco Leste',
            'zeis_pde' : 'ZEIS-1',
            'eixo_estruturacao_urbana' : 'eixo previsto'
            },
        'zoneamento' : 'ZEU',
        'leis_especificas' : 
            {
            'operacao_urbana' : 'Água Branca',
            'aiu' : 'Vila Andrade',
            },
        'leis_especiais' : {
            'requalifica_centro' : False,
            'mirante_de_santana' : False,            
        },
    'limitacoes_a_propriedade' : {
        'melhoramento_viario' : [
             {
                 'numero_lei' : 'AAA/1990',
                 'data_publicacao' : 'dia/mes/ano'
             }
        ],
        'dis_e_dup' : [
                        {
                            'numero_decreto' : 'AAA/1990',
                            'data_publicacao' : 'dia/mes/ano',
                            'ente' : 'Prefeitura de São Paulo',
                            'tipo' : 'DIS'
                        },
                        {
                            'numero_decreto' : 'AAA/1990',
                            'data_publicacao' : 'dia/mes/ano',
                            'ente' : 'Governo do Estado de São Paulo',
                            'tipo' : 'DUP'
                        }
                    ],
        'faixas_dominio' : {
                'dutovia' : False,
                'estrada_e_rodovia' : False,
                'linha_de_transmissao' : False,
                'ferrovia' : False,
            },
        'area_publica' : {
            
        },
        },
    'terra_indigena' : {
        'nome_terra' : 'Guarani Zona Sul'
        },
    
    }
}
